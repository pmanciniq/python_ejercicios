# %%
import sys
import pandas as pd

# %%
#ejercicios pandas 1
#1) importa pandas
#2) Crea una Serie de los numeros 10, 20 and 10.
#3) Crea una Serie con tres objetos: 'rojo', 'verde', 'azul'
#4) Crea un dataframe vacío llamado 'df'
#5) Crea una nueva columna en el dataframe, y asignale la primera serie que has creado
#6) Crea otra columna en el dataframe y asignale la segunda Serie que has creado
#7) # Lee el archivo llamado 'avengers.csv" localizado en la carpeta "data" y crea un DataFrame, llamado 'avengers'. 
#     El archivo está localizado en "data/avengers.csv"
#8) Muestra las primeras 5 filas del DataFrame.
#9) Muestra las primeras 10 filas del DataFrame.
#10) Muestra las últimas 5 filas del DataFrame.
#11) Muestra el tamaño del DataFrame
#12) Muestra los data types del dataframe
#13) Cambia el indice a la columna "fecha_inicio".
#14) Ordena el índice de forma descendiente
#15) Resetea el índice

# %%
#no sabia como resolver, asi que investigué. Pandas tiene tres tipos de datos:
#Series
#DataFrames
#Panel

#Las Series se pueden crear a partir de diccionarios -> Series(data=diccionario, index=indices).

#2) Crea una Serie de los numeros 10, 20 and 10.

serie = pd.Series([10,20,10])
serie
# Out:
# 0    10
# 1    20
# 2    10
# dtype: int64

# %%
#3) Crea una Serie con tres objetos: 'rojo', 'verde', 'azul'
serie_colores = pd.Series(["rojo", "verde", "azul"])
serie_colores
# Out:
# 0     rojo
# 1    verde
# 2     azul
# dtype: object

# %%
#4) Crea un dataframe vacío llamado 'df'
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#5) Crea una nueva columna en el dataframe, y asignale la primera serie que has creado
df["Serie"] = serie
df
# Out:
#    Serie
# 0     10
# 1     20
# 2     10

# %%
#6) Crea otra columna en el dataframe y asignale la segunda Serie que has creado
df["Colores"] = serie_colores
df
# Out:
#    Serie Colores
# 0     10    rojo
# 1     20   verde
# 2     10    azul

# %%
#7) # Lee el archivo llamado 'avengers.csv" localizado en la carpeta "data" y crea un DataFrame, llamado 'avengers'. 
#     El archivo está localizado en "data/avengers.csv"
avengers = pd.read_csv("avengers.csv")
avengers
# Out:
#                                                    URL  \
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1    http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3    http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4     http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# ..                                                 ...
# 168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#
# 169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...
# 170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...
# 171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#
# 172         http://marvel.wikia.com/Kaluu_(Earth-616)#
#
#                           nombre  n_apariciones actual  genero  fecha_inicio  \
# 0      Henry Jonathan "Hank" Pym           1269    YES    MALE          1963
# 1                 Janet van Dyne           1165    YES  FEMALE          1963
# ...

# %%
#8) Muestra las primeras 5 filas del DataFrame.

avengers.head(5)
# Out:
#                                                  URL  \
# 0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
#
#                         nombre  n_apariciones actual  genero  fecha_inicio  \
# 0    Henry Jonathan "Hank" Pym           1269    YES    MALE          1963
# 1               Janet van Dyne           1165    YES  FEMALE          1963
# 2  Anthony Edward "Tony" Stark           3068    YES    MALE          1963
# 3          Robert Bruce Banner           2089    YES    MALE          1963
# 4                 Thor Odinson           2402    YES    MALE          1963
#
#                                                Notes
# 0  Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1  Dies in Secret Invasion V1:I8. Actually was se...
# ...

# %%
#9) Muestra las primeras 10 filas del DataFrame.
avengers.head(10)
# Out:
#                                                  URL  \
# 0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 5  http://marvel.wikia.com/Richard_Jones_(Earth-616)
# 6  http://marvel.wikia.com/Steven_Rogers_(Earth-616)
# 7   http://marvel.wikia.com/Clint_Barton_(Earth-616)
# 8  http://marvel.wikia.com/Pietro_Maximoff_(Earth...
# 9  http://marvel.wikia.com/Wanda_Maximoff_(Earth-...
#
#                         nombre  n_apariciones actual  genero  fecha_inicio  \
# 0    Henry Jonathan "Hank" Pym           1269    YES    MALE          1963
# 1               Janet van Dyne           1165    YES  FEMALE          1963
# 2  Anthony Edward "Tony" Stark           3068    YES    MALE          1963
# 3          Robert Bruce Banner           2089    YES    MALE          1963
# ...

# %%
#10) Muestra las últimas 5 filas del DataFrame.
avengers.tail(5)
# Out:
#                                                    URL          nombre  \
# 168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#     Eric Brooks
# 169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...   Adam Brashear
# 170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...  Victor Alvarez
# 171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#       Ava Ayala
# 172         http://marvel.wikia.com/Kaluu_(Earth-616)#           Kaluu
#
#      n_apariciones actual  genero  fecha_inicio Notes
# 168            198    YES    MALE          2013   NaN
# 169             29    YES    MALE          2014   NaN
# 170             45    YES    MALE          2014   NaN
# 171             49    YES  FEMALE          2014   NaN
# 172             35    YES    MALE          2015   NaN

# %%
#11) Muestra el tamaño del DataFrame

avengers.shape
# Out:
# (173, 7)

# %%
#12) Muestra los data types del dataframe
avengers.dtypes
# Out:
# URL              object
# nombre           object
# n_apariciones     int64
# actual           object
# genero           object
# fecha_inicio      int64
# Notes            object
# dtype: object

# %%
#13) Cambia el indice a la columna "fecha_inicio".
avengers.set_index("fecha_inicio")
# Out:
#                                                             URL  \
# fecha_inicio
# 1963              http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1963          http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 1963          http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 1963          http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 1963           http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# ...                                                         ...
# 2013           http://marvel.wikia.com/Eric_Brooks_(Earth-616)#
# 2014          http://marvel.wikia.com/Adam_Brashear_(Earth-6...
# 2014          http://marvel.wikia.com/Victor_Alvarez_(Earth-...
# 2014             http://marvel.wikia.com/Ava_Ayala_(Earth-616)#
# 2015                 http://marvel.wikia.com/Kaluu_(Earth-616)#
#
#                                    nombre  n_apariciones actual  genero  \
# fecha_inicio
# 1963            Henry Jonathan "Hank" Pym           1269    YES    MALE
# ...

# %%
#14) Ordena el índice de forma descendiente
avengers.sort_index(ascending=False)
# Out:
#      index                                                URL  \
# 172      0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 171      1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 170      2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 169      3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 168      4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# ..     ...                                                ...
# 4      168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#
# 3      169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...
# 2      170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...
# 1      171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#
# 0      172         http://marvel.wikia.com/Kaluu_(Earth-616)#
#
#                           nombre  n_apariciones actual  genero  fecha_inicio  \
# 172    Henry Jonathan "Hank" Pym           1269    YES    MALE          1963
# ...

# %%
#15) Resetea el índice
avengers = avengers.reset_index()
avengers
# Out:
#      level_0  index                                                URL  \
# 0          0    172         http://marvel.wikia.com/Kaluu_(Earth-616)#
# 1          1    171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#
# 2          2    170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...
# 3          3    169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...
# 4          4    168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#
# ..       ...    ...                                                ...
# 168      168      4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 169      169      3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 170      170      2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 171      171      1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 172      172      0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
#
#                           nombre  n_apariciones actual  genero  fecha_inicio  \
# ...

# %%
# !git add *
#actualizamos repositorio
# Out:
# ...
# The file will have its original line endings in your working directory
# ...
# The file will have its original line endings in your working directory
# ...
# The file will have its original line endings in your working directory
# ...
# The file will have its original line endings in your working directory
# ...
# The file will have its original line endings in your working directory

# %%
# !git commit -m "actualizando repo de ejercicios"
# Out:
# [main f19c93d] actualizando repo de ejercicios
#  6 files changed, 16901 insertions(+), 4 deletions(-)
#  create mode 100644 .ipynb_checkpoints/ejercicios_pandas_1-checkpoint.ipynb
#  create mode 100644 airbnb.csv
#  create mode 100644 avengers.csv
#  create mode 100644 ejercicios_pandas_1.ipynb

# %%
# !git push
# Out:
# To https://github.com/pmanciniq/python_ejercicios.git
#    450df95..f19c93d  main -> main
